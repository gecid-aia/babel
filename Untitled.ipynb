# %%
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.figure(figsize=(14,8))
nx.draw_networkx(G, node_color = 'purple', edge_color = 'black', node_size = 1000)
plt.draw()
